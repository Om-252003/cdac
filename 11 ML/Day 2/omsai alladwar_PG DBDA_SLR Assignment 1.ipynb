# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("SLRAssignment1_Dataset.xlsx")
df
# Out:
#      X      y
# 0  100  212.0
# 1  105  221.0
# 2  110  230.0
# 3   82  179.6
# 4   76  168.8
# 5   45  113.0
# 6  -10   14.0
# 7  -50  -58.0
# 8 -100 -148.0

# %% [markdown]
# # Find the coefficient and the intercept and test it with some values. Target is y. Predictor is X

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       9 non-null      int64
#  1   y       9 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 276.0 bytes

# %%
df[['X','y']].corr()['X']
# Out:
# X    1.0
# y    1.0
# Name: X, dtype: float64

# %%
plt.figure(figsize=(5,3))
plt.scatter(df['X'],df['y'])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[['X']]
y = df[['y']]
print(X.shape, y.shape)
# Out:
# (9, 1) (9, 1)

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [[1.8]]

# %%
print(model.intercept_)
# Out:
# [32.]

# %% [markdown]
#  ## Y = 1.8 * X + 32

# %%
# test_vals = np.array([126,-172.2, 23, 49, 92, 88, 55, 66, -66]).reshape(-1,1) 
# test_vals.shape

test_vals = pd.DataFrame(
    [126,-172.2, 23, 49, 92, 88, 55, 66, -66],
    columns=["X"]
)
test_vals.shape
# Out:
# (9, 1)

# %%
yhat = model.predict(test_vals)
print(np.round(yhat, 2))
# Out:
# [[ 258.8 ]
#  [-277.96]
#  [  73.4 ]
#  [ 120.2 ]
#  [ 197.6 ]
#  [ 190.4 ]
#  [ 131.  ]
#  [ 150.8 ]
#  [ -86.8 ]]

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
plt.scatter(df['X'], df['y'], c='red', label='Actual')
plt.legend(loc='upper left')
plt.subplot(2,2,2)
plt.scatter(df['X'], model.predict(X), c='blue', label='Predicted')
plt.legend(bbox_to_anchor=(1.2,1))
plt.show()
