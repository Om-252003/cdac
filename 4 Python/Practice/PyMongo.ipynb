# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\raghu\anaconda3\lib\site-packages (3.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install pymongo
from pymongo import MongoClient
# pprint library is used to make the output look more pretty
from pprint import pprint
from random import randint
client = MongoClient("localhost:27017")
#let's connect to greatlearning database, and insert 1000 documents containing product name, company name and rating

db = client['greatlearning']
productcollection = db['product_feedback']

#
productlist = []
product_name = ['Mobile','TV','Washing machine', 'Refrigerator', 'Microwave Oven','Induction cooker','AC']
company_name = ['LG', 'Samsung', 'Bosch','Siemens','Whirlpool','Electrolux','Haier','Videocon']
for x in range(1, 1001):
    sale = {
        'name' : product_name[randint(0, (len(product_name)-1))],
        'rating' : randint(1, 5),
        'brand' : company_name[randint(0, (len(company_name)-1))] 
    }
    productlist.append(sale)
    
productcollection.insert_many(productlist)

# %% [markdown]
# Once, we have inserted 1000 documents then we can peform different CRUD operations using PyMongo.
# Let say , we want to find those products which have recived 5/5 rating.

# %%
rating5reviews= productcollection.find({"rating":5})
for  review in rating5reviews:
    print(review)
# Out:
# {'_id': ObjectId('6224a196ad1a0c376e63441c'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63441f'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634420'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634421'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634427'), 'name': 'AC', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63443c'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e63443e'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634442'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634444'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634446'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634451'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634452'), 'name': 'Mobile', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634464'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634466'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63446a'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63447c'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634480'), 'name': 'TV', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634483'), 'name': 'AC', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634485'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e63448b'), 'name': 'Mobile', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63449e'), 'name': 'AC', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6344a1'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6344a3'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6344a5'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6344b5'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6344ba'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6344bf'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6344c1'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6344c2'), 'name': 'AC', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6344cb'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6344cd'), 'name': 'Mobile', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6344d0'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6344d3'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e6344d9'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6344db'), 'name': 'TV', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6344df'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6344e0'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e6344e6'), 'name': 'Mobile', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6344e8'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6344f0'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6344f1'), 'name': 'AC', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6344f8'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6344fb'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634503'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634504'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e63450a'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63450b'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63450f'), 'name': 'Mobile', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634511'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634515'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e63451b'), 'name': 'AC', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e63451c'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63451f'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634523'), 'name': 'AC', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63452c'), 'name': 'Washing machine', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e63452d'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634532'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634534'), 'name': 'TV', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634539'), 'name': 'Mobile', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634540'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634543'), 'name': 'AC', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634544'), 'name': 'Mobile', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e63454c'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e63454e'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634553'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634557'), 'name': 'Mobile', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634563'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634568'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63456d'), 'name': 'AC', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634571'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634573'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634579'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e63457d'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634580'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63458c'), 'name': 'TV', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634595'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634599'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63459e'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6345a8'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6345a9'), 'name': 'TV', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6345b7'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6345bc'), 'name': 'AC', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6345c3'), 'name': 'TV', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6345c5'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6345c6'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6345c7'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6345c8'), 'name': 'TV', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e6345cb'), 'name': 'TV', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6345cd'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6345d6'), 'name': 'TV', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6345d7'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6345da'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6345e1'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6345e7'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6345eb'), 'name': 'Mobile', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e6345ee'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6345f0'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6345f2'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6345f4'), 'name': 'TV', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e6345fb'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6345fd'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634603'), 'name': 'Mobile', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634606'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63460d'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634611'), 'name': 'Mobile', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634612'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634617'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634619'), 'name': 'AC', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634621'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634623'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634626'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634630'), 'name': 'AC', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634633'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634639'), 'name': 'AC', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e63463d'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63463f'), 'name': 'AC', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634645'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634648'), 'name': 'Mobile', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e63464c'), 'name': 'TV', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63464d'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63464e'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e63464f'), 'name': 'AC', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634651'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634653'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634654'), 'name': 'Mobile', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634655'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63465c'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63467b'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63467e'), 'name': 'Mobile', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e634681'), 'name': 'TV', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634682'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634688'), 'name': 'AC', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63468d'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634696'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634697'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6346a2'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6346a5'), 'name': 'Mobile', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6346a8'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6346a9'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6346b5'), 'name': 'Mobile', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6346bf'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6346cb'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6346cd'), 'name': 'AC', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6346cf'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6346d0'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6346d8'), 'name': 'AC', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6346db'), 'name': 'TV', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6346e5'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6346e8'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6346ea'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6346eb'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e6346f3'), 'name': 'Mobile', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6346f5'), 'name': 'Mobile', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6346fe'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634700'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634704'), 'name': 'Mobile', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634707'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e63470c'), 'name': 'TV', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63470e'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634710'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634715'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e634716'), 'name': 'TV', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e634719'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634728'), 'name': 'AC', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63472c'), 'name': 'Mobile', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63472e'), 'name': 'AC', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634732'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e63473a'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63473c'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634740'), 'name': 'TV', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634747'), 'name': 'Induction cooker', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e63474b'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634750'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634755'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634757'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634760'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e634763'), 'name': 'Mobile', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634769'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e634774'), 'name': 'TV', 'rating': 5, 'brand': 'Haier'}
# {'_id': ObjectId('6224a196ad1a0c376e63477d'), 'name': 'AC', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e63477e'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63478c'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e634790'), 'name': 'Mobile', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e634792'), 'name': 'Mobile', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e634795'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Whirlpool'}
# {'_id': ObjectId('6224a196ad1a0c376e63479a'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6347a0'), 'name': 'Mobile', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6347a9'), 'name': 'TV', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6347ac'), 'name': 'Mobile', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6347af'), 'name': 'Mobile', 'rating': 5, 'brand': 'Samsung'}
# {'_id': ObjectId('6224a196ad1a0c376e6347b3'), 'name': 'Mobile', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6347b5'), 'name': 'Microwave Oven', 'rating': 5, 'brand': 'Videocon'}
# {'_id': ObjectId('6224a196ad1a0c376e6347bb'), 'name': 'TV', 'rating': 5, 'brand': 'Electrolux'}
# {'_id': ObjectId('6224a196ad1a0c376e6347c5'), 'name': 'Washing machine', 'rating': 5, 'brand': 'Bosch'}
# {'_id': ObjectId('6224a196ad1a0c376e6347e6'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'LG'}
# {'_id': ObjectId('6224a196ad1a0c376e6347e7'), 'name': 'Refrigerator', 'rating': 5, 'brand': 'Siemens'}
# {'_id': ObjectId('6224a196ad1a0c376e6347ef'), 'name': 'AC', 'rating': 5, 'brand': 'Bosch'}

# %% [markdown]
# Let's count how many of reviws feedback have given 5/5 of rating and which brand has maximum 5/5 of ratings

# %%
pprint(productcollection.count_documents({"rating":5}))

#to findout which brand has got maximum 5/5 rating we need to use aggregation pipeline
from bson.son import SON
pipeline = [{"$match": {"rating": 5}},{"$group": {"_id": "$brand", "count": {"$sum": 1}}},{"$sort": SON([("count", -1), ("_id", -1)])}]
pprint(list(productcollection.aggregate(pipeline)))

# %% [markdown]
# Now, same aggregation logic,we will implement using MapRedcue framework. Here we will define map and reduce functions to also count the number of 5rating received by a particular brand, across the entire collection.
#
# Our map function just emits a single (brand, 1) pair if rating is 5

# %%
from bson.code import Code
mapper = Code("""
              function () {
                   if(this.rating == 5)
                     emit(this.brand, 1);
                 
               }
               """)

reducer = Code("""
                function (key, values) {
                  var total = 0;
                  for (var i = 0; i < values.length; i++) {
                    total += values[i];
                  }
                  return total;
                }
                """)


productcollection.map_reduce(mapper, reducer,"myresults")
result = db['myresults'].find()
for doc in result:
   pprint(doc)

# %% [markdown]
# let's update those records where product name is AC to "Air conditioner"

# %%
productcollection.update_many({"name": "AC"},{"$set": {"name": "Air conditioner"} })
for doc in productcollection.find({"name": "Air conditioner"}):
   pprint(doc)
